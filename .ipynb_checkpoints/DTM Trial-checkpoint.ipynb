# %%
# %pylab inline
#from datascience import *
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import re
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def process(directory_name, num_files, doc_type=".txt"):
    table = pd.DataFrame()
    all_files = os.fsencode(directory_name)
    stop = num_files
    start = 1
    index = 0
    
    for file in os.listdir(all_files):
            filename = os.fsdecode(file)
            if filename.endswith(".txt"): #".txt"
                with open(directory_name + filename, 'r') as text_file:
                    one_doc = text_file.read()
                    one_doc_list = one_doc.split(':')
                    one_doc_list = [word for word in one_doc_list if '[' in word]
                    table["text_" + str(index)] = pd.Series(one_doc_list)
                    num_files += 1
                    index += 1
                if(start >= stop):
                    return table
                start += 1
            else:
                continue
    
    return table


test_table = process('corpus/', 5)
test_table = pd.DataFrame.transpose(test_table)
test_table
# Out:
#                                                        0   \
# text_0  dubsaŋ[first]AJ\nc.0.1.1,Ur III catalogue from...
# text_1                                  diŋir[deity]N sux
# text_2                                   lugal[king]N sux
# text_3                                     Enlil[1]DN sux
# text_4                                   lugal[king]N sux
#
#                                                        1   \
# text_0                                      Enki[1]DN sux
# text_1                               šembizida[kohl]N sux
# text_2  šag[heart]N\nc.0.2.01,OB catalogue from Nibru ...
# text_3  sud[distant]V/i\nc.0.2.02,OB catalogue in the ...
# text_4                                      mu[name]N sux
#
#                                                        2   \
# text_0                                 unu[dwelling]N sux
# text_1  dar[split]V/t\nc.0.1.2,Ur III catalogue at Yal...
# text_2                                   lugal[king]N sux
# text_3                                     nam[lord]N sux
# text_4  niŋul[everlasting]N\nc.0.2.03,OB catalogue fro...
#
#                                                        3   \
# text_0                                    gal[big]V/i sux
# text_1                                     Enlil[1]DN sux
# text_2                                      mi[cvne]N sux
# text_3  nun[prince]N\nc.0.2.02,OB catalogue in the Lou...
# text_4                                  Waradsin[1]RN sux
#
#                                                        4   \
# text_0  ed[ascend]V/i\nc.0.1.1,Ur III catalogue from N...
# text_1                                  dug[speak]V/t sux
# text_2  dug[speak]V/t\nc.0.2.01,OB catalogue from Nibr...
# text_3                                       ud[sun]N sux
# text_4  lugal[king]N\nc.0.2.03,OB catalogue from Urim ...
#
#                                                        5   \
# text_0  anzag[horizon]N\nc.0.1.1,Ur III catalogue from...
# text_1  kur[different]V/i\nc.0.1.2,Ur III catalogue at...
# text_2                                      en[lord]N sux
# text_3  re[that]DP\nc.0.2.02,OB catalogue in the Louvr...
# text_4                                      Inab[1]SN sux
#
#                                                        6                 7   \
# text_0                                 anŋi[eclipse]N sux   zu[know]V/t sux
# text_1                                   lugal[king]N sux      an[sky]N sux
# text_2  niŋdu[appropriate-thing]N\nc.0.2.01,OB catalog...    nin[lady]N sux
# text_3                                   innin[lady]N sux    me[Being]N sux
# text_4  me[be]V/i\nc.0.2.03,OB catalogue from Urim (U1...  ŋuruš[male]N sux
#
#                                                        8   \
# text_0                                   ama[mother]N sux
# text_1                                   kug[pure]V/i sux
# text_2                                     me[Being]N sux
# text_3  huš[reddish]V/i\nc.0.2.02,OB catalogue in the ...
# text_4                                    lu[person]N sux
#
#                                                        9   \
# text_0                               tu[incantation]N sux
# text_1  mete[appropriate-thing]N\nc.0.1.2,Ur III catal...
# text_2  šar[3600]NU\nc.0.2.01,OB catalogue from Nibru ...
# text_3                                      e[house]N sux
# text_4                                     šir[song]N sux
#
#                               ...                          \
# text_0                        ...
# text_1                        ...
# text_2                        ...
# text_3                        ...
# text_4                        ...
#
#                                                        44  \
# text_0                                    lu[person]N sux
# text_1  zu[know]V/t\nc.0.1.2,Ur III catalogue at Yale ...
# text_2                               saŋki[forehead]N sux
# text_3                                 ul[distant]V/i sux
# text_4                                       an[sky]N sux
#
#                                                        45  \
# text_0                                    inim[word]N sux
# text_1                                    Šulgir[1]RN sux
# text_2  gid[long]V/i\nc.0.2.01,OB catalogue from Nibru...
# text_3  re[that]DP\nc.0.2.02,OB catalogue in the Louvr...
# text_4  ki[place]N\nc.0.2.03,OB catalogue from Urim (U...
#
#                                                        46  \
# text_0  zid[right]V/i\nc.0.1.1,Ur III catalogue from N...
# text_1                          hili[attractiveness]N sux
# text_2                                    eden[back]N sux
# text_3                             kiʾur[foundation]N sux
# text_4  ugu[skull]N\nc.0.2.03,OB catalogue from Urim (...
#
#                                                        47  \
# text_0                                ŋiriŋena[path]N sux
# text_1  sud[distant]V/i\nc.0.1.2,Ur III catalogue at Y...
# text_2                                     ilu[song]N sux
# text_3  gal[big]V/i\nc.0.2.02,OB catalogue in the Louv...
# text_4  Lugalbanda[1]DN\nc.0.2.03,OB catalogue from Ur...
#
#                                                        48  \
# text_0                                    lu[person]N sux
# text_1                                    Šulgir[1]RN sux
# text_2  ŋar[place]V/t\nc.0.2.01,OB catalogue from Nibr...
# text_3                                       ud[sun]N sux
# text_4                                     ud[storm]N sux
#
#                                                        49  \
# text_0  pad[find]V/t\nc.0.1.1,Ur III catalogue from Ni...
# text_1                                  diŋir[deity]N sux
# text_2                                       ud[sun]N sux
# text_3                                 ul[distant]V/i sux
# text_4                               ešbar[decision]N sux
#
#                                                        50  \
# text_0  ŋiriŋena[path]N\nc.0.1.1,Ur III catalogue from...
# text_1  zid[right]V/i\nc.0.1.2,Ur III catalogue at Yal...
# text_2  re[that]DP\nc.0.2.01,OB catalogue from Nibru (...
# text_3                                       an[sky]N sux
# text_4  kiŋ[seek]V/t\nc.0.2.03,OB catalogue from Urim ...
#
#                                                        51  \
# text_0                                 iribala[city]N sux
# text_1                                      en[lord]N sux
# text_2                                       ud[sun]N sux
# text_3  ki[place]N\nc.0.2.02,OB catalogue in the Louvr...
# text_4  Uduluru[1]PN\nc.0.2.03,OB catalogue from Urim ...
#
#                                                        52  \
# text_0                                     aš[curse]N sux
# text_1                                galanzu[wise]AJ sux
# text_2  re[that]DP\nc.0.2.01,OB catalogue from Nibru (...
# text_3  Lugalbanda[1]DN\nc.0.2.02,OB catalogue in the ...
# text_4                                      ma[ship]N sux
#
#                                                        53
# text_0                                    dug[speak]V/t\n
# text_1  an[sky]N\nc.0.1.2,Ur III catalogue at Yale (Y1...
# text_2                                     iri[city]N sux
# text_3                                     iri[city]N sux
# text_4  niŋ[thing]N\nc.0.2.03,OB catalogue from Urim (...
#
# [5 rows x 54 columns]
